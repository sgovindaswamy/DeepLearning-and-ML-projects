# %% [markdown]
# # This dataset consist of aerial images of Dubai obtained from satellite.
#
# There are 6 classes
#
# 1) Building
# 2) land
# 3) Road
# 4) Vegetation
# 5) Water
# 6) Unlabelled

# %%
pip install patchify
# Out:
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\sanja\anaconda3\lib\site-packages (from patchify) (1.21.5)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting image-classifiers==1.0.0
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.7/50.7 kB 2.5 MB/s eta 0:00:00
# Collecting efficientnet==1.0.0
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in c:\users\sanja\anaconda3\lib\site-packages (from efficientnet==1.0.0->segmentation-models) (0.19.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\sanja\anaconda3\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.21.5)
# Requirement already satisfied: h5py in c:\users\sanja\anaconda3\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.7.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\sanja\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sanja\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: networkx>=2.2 in c:\users\sanja\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.8.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sanja\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.9.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\sanja\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.19.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\sanja\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.2.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\sanja\anaconda3\lib\site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2021.7.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sanja\anaconda3\lib\site-packages (from packaging>=20.0->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.9)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#      --------------------------------------- 35.6/35.6 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sanja\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Collecting keras
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 26.6 MB/s eta 0:00:00
# Installing collected packages: keras
# Successfully installed keras-2.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sanja\\Downloads\\SG'

# %%
import os 
import numpy as np
import cv2 
from matplotlib import pyplot as plt 
from patchify import patchify 
from PIL import Image 
import segmentation_models as sm 
from tensorflow.keras.metrics import MeanIoU
from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\segmentation_models\__init__.py in <module>
#      97 try:
# ---> 98     set_framework(_framework)
#      99 except ImportError:
#
# ~\anaconda3\lib\site-packages\segmentation_models\__init__.py in set_framework(name)
#      66     if name == _KERAS_FRAMEWORK_NAME:
# ---> 67         import keras
#      68         import efficientnet.keras  # init custom objects
#
# ModuleNotFoundError: No module named 'keras'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18112\1566221473.py in <module>
#       5 from patchify import patchify
#       6 from PIL import Image
# ----> 7 import segmentation_models as sm
#       8 from tensorflow.keras.metrics import MeanIoU
#       9 from sklearn.preprocessing import MinMaxScaler, StandardScaler
#
# ~\anaconda3\lib\site-packages\segmentation_models\__init__.py in <module>
#      99 except ImportError:
#     100     other = _TF_KERAS_FRAMEWORK_NAME if _framework == _KERAS_FRAMEWORK_NAME else _KERAS_FRAMEWORK_NAME
# --> 101     set_framework(other)
#     102
#     103 print('Segmentation Models: using `{}` framework.'.format(_KERAS_FRAMEWORK))
#
# ~\anaconda3\lib\site-packages\segmentation_models\__init__.py in set_framework(name)
#      68         import efficientnet.keras  # init custom objects
#      69     elif name == _TF_KERAS_FRAMEWORK_NAME:
# ---> 70         from tensorflow import keras
#      71         import efficientnet.tfkeras  # init custom objects
#      72     else:
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
root_directory = 'aerial_imagery_32MB/'

patch_size = 256

# %% [markdown]
# # Preprocessing the images

# %%
image_dataset = []  
for path, subdirs, files in os.walk(root_directory):
   
    dirname = path.split(os.path.sep)[-1]
    print(path)
    
    #print(dirname)
    if dirname == 'images':
        images = os.listdir(path)
        images.sort()
        print(images)
        
        for i, imagenames in enumerate(images):
            if imagenames.endswith(".jpg"):
                
                image = cv2.imread(path+"/"+imagenames, 1)
                nearest_width = (image.shape[1] // patch_size)*patch_size
                nearest_height = (image.shape[0] // patch_size)*patch_size
                image = Image.fromarray(image)
                image = image.crop((0, 0, nearest_width, nearest_height))
                image = np.array(image)
                
                
                #extract patches from each image
                
                #print("patchifying the image :", path+"/"+imagenames)
                patches_of_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)
                #print(patches_of_img.shape)
                
                for i in range(patches_of_img.shape[0]):
                    for j in range(patches_of_img.shape[1]):
                        single_patch_img = patches_of_img[i, j, :, :]
            
                        scaler = MinMaxScaler() 
                        single_patch_img = scaler.fit_transform(single_patch_img.reshape(
                            -1,single_patch_img.shape[-1])).reshape(single_patch_img.shape)
                        single_patch_img = single_patch_img[0] #dropping the extra 1
                        #print(single_patch_img.shape)
                        
                        image_dataset.append(single_patch_img)
# Out:
# aerial_imagery_32MB/
# aerial_imagery_32MB/2
# aerial_imagery_32MB/2/masks
# aerial_imagery_32MB/2/images
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']
# aerial_imagery_32MB/6
# aerial_imagery_32MB/6/masks
# aerial_imagery_32MB/6/images
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']
# aerial_imagery_32MB/.ipynb_checkpoints
# aerial_imagery_32MB/3
# aerial_imagery_32MB/3/masks
# aerial_imagery_32MB/3/images
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']
# aerial_imagery_32MB/5
# aerial_imagery_32MB/5/masks
# aerial_imagery_32MB/5/images
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']
# aerial_imagery_32MB/8
# aerial_imagery_32MB/8/masks
# aerial_imagery_32MB/8/images
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']
# aerial_imagery_32MB/1
# aerial_imagery_32MB/1/masks
# aerial_imagery_32MB/1/images
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']
# aerial_imagery_32MB/7
# aerial_imagery_32MB/7/masks
# aerial_imagery_32MB/7/images
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']
# aerial_imagery_32MB/4
# aerial_imagery_32MB/4/masks
# aerial_imagery_32MB/4/images
# ['1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg', '8.jpg', '9.jpg']

# %% [markdown]
# # Preprocessing the masks (similar to images)

# %%
root_directory = 'aerial_imagery_32MB/'

patch_size = 256

# %%
mask_dataset = []

for path, subdirs, files in os.walk(root_directory):
    print(path)
    
    dirnames = path.split(os.path.sep)[-1]
   
    #print(dirnames)
    
    if dirnames == "masks":
        masks = os.listdir(path)
        #listdir gets the list of all the files in the specified path 
        masks.sort()
        print(masks)
        
        for i, maskname in enumerate(masks):
            if maskname.endswith(".png"):
                mask = cv2.imread(path+"/"+maskname, 1)
                mask = cv2.cvtColor(mask, cv2.COLOR_RGB2BGR)
                nearest_width = (mask.shape[1]//patch_size)*patch_size
                nearest_height = (mask.shape[0]//patch_size)*patch_size
                
                mask = Image.fromarray(mask)
                mask = mask.crop((0, 0, nearest_width, nearest_height))
                mask = np.array(mask)
                #print(len(mask))
                
                #print("Patchifying the mask", path+"/"+maskname)
                mask_patches = patchify(mask, (patch_size, patch_size, 3), step=patch_size)
                #print(mask_patches.shape)
                #print(mask_patches)
                
                for i in range(mask_patches.shape[0]):
                    for j in range(mask_patches.shape[1]):
                        single_mask_patch = mask_patches[i, j, :, :]
                        single_mask_patch = single_mask_patch[0]
                        #print(single_mask_patch.shape)
                        
                        mask_dataset.append(single_mask_patch)
                        #print(len(mask_dataset))
# Out:
# aerial_imagery_32MB/
# aerial_imagery_32MB/2
# aerial_imagery_32MB/2/masks
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# aerial_imagery_32MB/2/images
# aerial_imagery_32MB/6
# aerial_imagery_32MB/6/masks
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# aerial_imagery_32MB/6/images
# aerial_imagery_32MB/.ipynb_checkpoints
# aerial_imagery_32MB/3
# aerial_imagery_32MB/3/masks
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# aerial_imagery_32MB/3/images
# aerial_imagery_32MB/5
# aerial_imagery_32MB/5/masks
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# aerial_imagery_32MB/5/images
# aerial_imagery_32MB/8
# aerial_imagery_32MB/8/masks
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# aerial_imagery_32MB/8/images
# aerial_imagery_32MB/1
# aerial_imagery_32MB/1/masks
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# aerial_imagery_32MB/1/images
# aerial_imagery_32MB/7
# aerial_imagery_32MB/7/masks
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# aerial_imagery_32MB/7/images
# aerial_imagery_32MB/4
# aerial_imagery_32MB/4/masks
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png', '7.png', '8.png', '9.png']
# aerial_imagery_32MB/4/images

# %%
image_dataset = np.array(image_dataset)
mask_dataset = np.array(mask_dataset)

# %% [markdown]
# # Sanity check between a random image and its corresponding mask

# %%
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()

# %% [markdown]
# # hexadecimal values
#
# 0 to 9 = 0 to 9 ;
# 10 to 15 = A to F
#
# There are 6 classes/labels in this semantic segmentation problem. For this 6 classes/labels, we need to convert the given HEX decimal code into RGB

# %% [markdown]
# # Calculate the HEX code into RGB values

# %%
building = '#3C1098'.lstrip('#')

building = np.array(tuple(int(building[i:i+2], 16)for i in (0, 2, 4)))
print("The RGB value of building: ", building)
# Out:
# The RGB value of building:  [ 60  16 152]

# %%
land =  '#8429F6'.lstrip('#')

land = np.array(tuple(int(land[i:i+2], 16)for i in (0, 2, 4)))
print("The RGB value of land: ", land)
# Out:
# The RGB value of land:  [132  41 246]

# %%
Road = '#6EC1E4'.lstrip('#')

Road = np.array(tuple(int(Road[i:i+2], 16)for i in (0, 2, 4)))
print("The RGB value of Road: ", Road)
# Out:
# The RGB value of Road:  [110 193 228]

# %%
Vegetation = '#FEDD3A'.lstrip('#')

Vegetation = np.array(tuple(int(Vegetation[i:i+2], 16)for i in (0, 2, 4)))
print("The RGB value of vegetation: ", Vegetation)
# Out:
# The RGB value of vegetation:  [254 221  58]

# %%
Water = '#E2A929'.lstrip('#')

Water = np.array(tuple(int(Water[i:i+2], 16)for i in (0, 2, 4)))
print("The RGB value of Water: ", Water)
# Out:
# The RGB value of Water:  [226 169  41]

# %%
Unlabeled = '#9B9B9B'.lstrip('#')

Unlabeled = np.array(tuple(int(Unlabeled[i:i+2], 16)for i in (0, 2, 4)))
print("The RGB value of Unlabeled: ", Unlabeled)
# Out:
# The RGB value of Unlabeled:  [155 155 155]

# %%
#Assinging the list of mask patches to a variable and performing integer encoding for each class

label = single_mask_patch

def rgb_to_2D_labels(label):
    label_for_classes = np.zeros(label.shape, dtype = np.uint8)
    label_for_classes[np.all(label == building, axis = -1)] = 0
    label_for_classes[np.all(label == land, axis = -1)] = 1
    label_for_classes[np.all(label == Road, axis = -1)] = 2
    label_for_classes[np.all(label == Vegetation, axis = -1)] = 3
    label_for_classes[np.all(label == Water, axis = -1)] = 4
    label_for_classes[np.all(label == Unlabeled, axis = -1)] = 5
    
    label_for_classes = label_for_classes[:, :, 0]
    
    return label_for_classes

# %%
len(mask_dataset)
# Out:
# 1305

# %%
#update the new labels to the mask dataset 

labels = []

for i in range(len(mask_dataset)):
    label = rgb_to_2D_labels(mask_dataset[i])
    labels.append(label)
    
labels = np.array(labels)
labels = np.expand_dims(labels, axis = 3)

# %%
#Sanity check to find the unique labels in the dataset
np.unique(labels)


import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()

# %%
# Convert the integer encoded values to one-hot encoded values 

n_classes = len(np.unique(labels))

from keras.utils import to_categorical
labels_categorical = to_categorical(labels, num_classes = n_classes)

# %%
from sklearn.model_selection import train_test_split

X_train, Y_train, X_test, Y_test = train_test_split(image_dataset, labels_categorical, 
                                                               test_size=0.20, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 X_train, Y_train, X_test, Y_test = train_test_split(image_dataset, labels_categorical,
#       4                                                                test_size=0.20, random_state=42)
#
# NameError: name 'image_dataset' is not defined
